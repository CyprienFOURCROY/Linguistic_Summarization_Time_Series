# %%
from functions import linear_piecewise_approximation
import numpy as np
# Example time series
X = np.arange(0, 20)
Y = np.array([1,2,3,3.5,4,4.1,3.9,3.8,3.7,3.6,3.7,4.2,5,6,6.5,6.8,7.0,7.1,7.1,7.0])

alphas, X_ranges = linear_piecewise_approximation(X, Y, epsilon=0.15)

for i, (a, (start, end)) in enumerate(zip(alphas, X_ranges)):
    print(f"Segment {i+1}: X[{start}:{end}]  angle={a:.3f}")
# Out:
# Segment 1: X[0:3]  angle=41.983
# Segment 2: X[3:5]  angle=19.837
# Segment 3: X[5:10]  angle=-5.640
# Segment 4: X[10:12]  angle=31.847
# Segment 5: X[12:14]  angle=39.611
# Segment 6: X[14:18]  angle=10.260
# Segment 7: X[18:19]  angle=-5.711

# %%
from functions import plot_time_series_with_segments_and_epsilon

# %%
plot_time_series_with_segments_and_epsilon(X, Y, alphas, X_ranges,epsilon=0.15)
